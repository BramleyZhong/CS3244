# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("./combined_match_data.csv")
df.head()
# Out:
#    Unnamed: 0       Date   Tm  Opp     Result  MP  FG  FGA    FG%  2P  ...  \
# 0           0  2021/3/27  LAC  PHI  W 122-112   0   6    8  0.023   5  ...
# 1           1  2021/3/27  MIL  NYK   L 96-102   0  -4   -6 -0.016  -2  ...
# 2           2  2021/3/27  HOU  MIN  W 129-107   0  14    7  0.119   9  ...
# 3           3  2021/3/27  DAL  NOP  L 103-112   0  -5    2 -0.073  -6  ...
# 4           4  2021/3/27  BOS  OKC   W 111-94   0  10   13  0.048   9  ...
#
#    DRB%_players  TRB%_players  AST%_players  STL%_players  BLK%_players  \
# 0      0.306965     -0.008681      1.911229      0.812160      0.494660
# 1      1.040604      0.856354     -3.154868      0.438028     -1.437743
# 2      0.118319      0.237764     -2.612667     -0.216451      0.844785
# 3      0.110549     -1.013229      0.323562      0.000597     -0.465271
# 4      0.158014      0.402292      0.302417      0.613111      0.396278
#
#    TOV%_players  USG%_players  ORtg_players  DRtg_players  BPM_players
# ...

# %%
# calculate A/T, efficiency(EFF) and EFFECTIVE FIELD GOAL PERCENTAGE 
df["A/T"] = df["AST_players"]/df["TOV_players"]
df["EFF"] = df["PTS_players"]+df["TRB_players"]+df["AST_players"]+df["STL_players"]+df["BLK_players"]
-(df["FGA_players"]-df["FG_players"])-(df["FTA_players"]-df["FT_players"])-df["TOV_players"]
df.head()
# Out:
#    Unnamed: 0       Date   Tm  Opp     Result  MP  FG  FGA    FG%  2P  ...  \
# 0           0  2021/3/27  LAC  PHI  W 122-112   0   6    8  0.023   5  ...
# 1           1  2021/3/27  MIL  NYK   L 96-102   0  -4   -6 -0.016  -2  ...
# 2           2  2021/3/27  HOU  MIN  W 129-107   0  14    7  0.119   9  ...
# 3           3  2021/3/27  DAL  NOP  L 103-112   0  -5    2 -0.073  -6  ...
# 4           4  2021/3/27  BOS  OKC   W 111-94   0  10   13  0.048   9  ...
#
#    AST%_players  STL%_players  BLK%_players  TOV%_players  USG%_players  \
# 0      1.911229      0.812160      0.494660      2.561424      0.008542
# 1     -3.154868      0.438028     -1.437743      0.861069      0.004507
# 2     -2.612667     -0.216451      0.844785     -2.610431      0.014319
# 3      0.323562      0.000597     -0.465271      3.850118      0.030243
# 4      0.302417      0.613111      0.396278     -2.840465     -0.013535
#
#    ORtg_players  DRtg_players  BPM_players       A/T       EFF
# ...

# %%
df.shape
# Out:
# (1143, 94)

# %%
df.to_csv('./combined_match_data_features.csv', index = 0)

# %%
df
# Out:
#       Unnamed: 0       Date   Tm  Opp     Result  MP  FG  FGA    FG%  2P  ...  \
# 0              0  2021/3/27  LAC  PHI  W 122-112   0   6    8  0.023   5  ...
# 1              1  2021/3/27  MIL  NYK   L 96-102   0  -4   -6 -0.016  -2  ...
# 2              2  2021/3/27  HOU  MIN  W 129-107   0  14    7  0.119   9  ...
# 3              3  2021/3/27  DAL  NOP  L 103-112   0  -5    2 -0.073  -6  ...
# 4              4  2021/3/27  BOS  OKC   W 111-94   0  10   13  0.048   9  ...
# ...          ...        ...  ...  ...        ...  ..  ..  ...    ...  ..  ...
# 1138        1141  2020/1/13  CLE  LAL   L 99-128   0 -10   -3 -0.098  -6  ...
# 1139        1142  2020/1/13  MIN  OKC  L 104-117   0  -3    9 -0.082  -3  ...
# 1140        1143  2020/1/13  CHO  POR  L 112-115   0  -2    7 -0.062  -4  ...
# 1141        1144  2020/1/13  ORL  SAC  W 114-112   0  -5    5 -0.082  -2  ...
# 1142        1151  2020/1/12  UTA  WAS  W 127-116   0   1   -3  0.028  -2  ...
#
# ...
