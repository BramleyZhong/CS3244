# %%
import pandas as pd
import numpy as np

# %%
df_match = pd.read_csv("./data(1).csv")

# %%
df_player = pd.read_csv("./match_player_data.csv")
# df_match = pd.read_csv("./match_data.csv")

# %%
df_player.head()
# Out:
#         Date   Tm  Opp     Result   MP  FG  FGA    FG%  2P  2PA  ...  \
# 0  2021/3/27  LAC  PHI  W 122-112  240  45   85  0.529  34   59  ...
# 1  2021/3/27  PHI  LAC  L 112-122  240  39   77  0.506  29   51  ...
# 2  2021/3/27  MIL  NYK   L 96-102  240  36   87  0.414  22   51  ...
# 3  2021/3/27  NYK  MIL   W 102-96  240  40   93  0.430  24   49  ...
# 4  2021/3/27  HOU  MIN  W 129-107  240  50   92  0.543  32   53  ...
#
#    DRB%_players  TRB%_players  AST%_players  STL%_players  BLK%_players  \
# 0     15.669340     10.003326     14.443854      1.839944      1.174243
# 1     15.362375     10.012007     12.532625      1.027785      0.679583
# 2     14.657694     10.419354     14.706986      2.358125      2.867201
# 3     13.617090      9.563000     17.861854      1.920097      4.304944
# 4     15.125660     10.108146     14.598562      1.453403      3.110354
#
#    TOV%_players  USG%_players  ORtg_players  DRtg_players  BPM_players
# 0     12.329424     20.008688    127.632847    114.770694     2.116778
# 1      9.768000     20.000146    115.643889    124.967014    -0.263049
# 2     12.894146     19.995618    102.328681    109.398819    -1.726819
# 3     12.033076     19.991111    111.053958    103.274306    -0.224799
# 4     12.017993     20.008312    133.320278    112.400069     0.879021
#
# [5 rows x 65 columns]

# %%
df_match.head()
# Out:
#    Unnamed: 0       Date   Tm  Opp     Result   MP  FG  FGA    FG%  2P  ...  \
# 0           0  2021/3/27  LAC  PHI  W 122-112  240  45   85  0.529  34  ...
# 1           1  2021/3/27  PHI  LAC  L 112-122  240  39   77  0.506  29  ...
# 2           2  2021/3/27  MIL  NYK   L 96-102  240  36   87  0.414  22  ...
# 3           3  2021/3/27  NYK  MIL   W 102-96  240  40   93  0.430  24  ...
# 4           4  2021/3/27  HOU  MIN  W 129-107  240  50   92  0.543  32  ...
#
#    2P_AVG.1  2PA_AVG.1  2P%_AVG.1  3P_AVG.1  3PA_AVG.1  3P%_AVG.1  FT_AVG.1  \
# 0      27.8       53.1     0.5246      12.0       31.2     0.3844      15.7
# 1      28.2       58.5     0.4820      10.2       28.4     0.3528      16.7
# 2      29.6       56.5     0.5247      14.3       39.8     0.3581      13.2
# 3      27.9       50.4     0.5591      11.9       31.7     0.3733      16.4
# 4      27.4       51.1     0.5405      14.2       37.6     0.3812      18.1
#
#    FTA_AVG.1  FT%_AVG.1  PTS_AVG.1
# 0       20.6     0.7788      107.3
# 1       24.3     0.6883      103.7
# 2       15.9     0.8382      115.3
# 3       22.2     0.7507      107.9
# 4       22.7     0.7985      115.5
#
# [5 rows x 58 columns]

# %%
# drop overlapping columns from player df
to_drop = []
for col_name in df_player.columns:
    if col_name in df_match.columns:
        to_drop.append(col_name)

df_player.drop(columns=to_drop, inplace=True)

# %%
merged_raw = df_match.join(df_player)

# %%
merged_raw.head()
# Out:
#    Unnamed: 0       Date   Tm  Opp     Result   MP  FG  FGA    FG%  2P  ...  \
# 0           0  2021/3/27  LAC  PHI  W 122-112  240  45   85  0.529  34  ...
# 1           1  2021/3/27  PHI  LAC  L 112-122  240  39   77  0.506  29  ...
# 2           2  2021/3/27  MIL  NYK   L 96-102  240  36   87  0.414  22  ...
# 3           3  2021/3/27  NYK  MIL   W 102-96  240  40   93  0.430  24  ...
# 4           4  2021/3/27  HOU  MIN  W 129-107  240  50   92  0.543  32  ...
#
#    DRB%_players  TRB%_players  AST%_players  STL%_players  BLK%_players  \
# 0     15.669340     10.003326     14.443854      1.839944      1.174243
# 1     15.362375     10.012007     12.532625      1.027785      0.679583
# 2     14.657694     10.419354     14.706986      2.358125      2.867201
# 3     13.617090      9.563000     17.861854      1.920097      4.304944
# 4     15.125660     10.108146     14.598562      1.453403      3.110354
#
#    TOV%_players  USG%_players  ORtg_players  DRtg_players  BPM_players
# 0     12.329424     20.008688    127.632847    114.770694     2.116778
# 1      9.768000     20.000146    115.643889    124.967014    -0.263049
# 2     12.894146     19.995618    102.328681    109.398819    -1.726819
# 3     12.033076     19.991111    111.053958    103.274306    -0.224799
# 4     12.017993     20.008312    133.320278    112.400069     0.879021
#
# [5 rows x 92 columns]

# %%
merged_raw.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'Tm', 'Opp', 'Result', 'MP', 'FG', 'FGA', 'FG%',
#        '2P', '2PA', '2P%', '3P', '3PA', '3P%', 'FT', 'FTA', 'FT%', 'PTS',
#        'FG.1', 'FGA.1', 'FG%.1', '2P.1', '2PA.1', '2P%.1', '3P.1', '3PA.1',
#        '3P%.1', 'FT.1', 'FTA.1', 'FT%.1', 'PTS.1', 'FG_AVG', 'FGA_AVG',
#        'FG%_AVG', '2P_AVG', '2PA_AVG', '2P%_AVG', '3P_AVG', '3PA_AVG',
#        '3P%_AVG', 'FT_AVG', 'FTA_AVG', 'FT%_AVG', 'PTS_AVG', 'FG_AVG.1',
#        'FGA_AVG.1', 'FG%_AVG.1', '2P_AVG.1', '2PA_AVG.1', '2P%_AVG.1',
#        '3P_AVG.1', '3PA_AVG.1', '3P%_AVG.1', 'FT_AVG.1', 'FTA_AVG.1',
#        'FT%_AVG.1', 'PTS_AVG.1', 'FG_players', 'FGA_players', 'FG%_players',
#        '3P_players', '3PA_players', '3P%_players', 'FT_players', 'FTA_players',
#        'FT%_players', 'ORB_players', 'DRB_players', 'TRB_players',
#        'AST_players', 'STL_players', 'BLK_players', 'TOV_players',
#        'PF_players', 'PTS_players', '+/-_players', 'TS%_players',
#        'eFG%_players', '3PAr_players', 'FTr_players', 'ORB%_players',
#        'DRB%_players', 'TRB%_players', 'AST%_players', 'STL%_players',
#        'BLK%_players', 'TOV%_players', 'USG%_players', 'ORtg_players',
#        'DRtg_players', 'BPM_players'],
#       dtype='object')

# %%
# drop unnecessary columns
merged_raw.drop(columns=['Unnamed: 0'], inplace=True)

# %%
merged_raw.head()
# Out:
#         Date   Tm  Opp     Result   MP  FG  FGA    FG%  2P  2PA  ...  \
# 0  2021/3/27  LAC  PHI  W 122-112  240  45   85  0.529  34   59  ...
# 1  2021/3/27  PHI  LAC  L 112-122  240  39   77  0.506  29   51  ...
# 2  2021/3/27  MIL  NYK   L 96-102  240  36   87  0.414  22   51  ...
# 3  2021/3/27  NYK  MIL   W 102-96  240  40   93  0.430  24   49  ...
# 4  2021/3/27  HOU  MIN  W 129-107  240  50   92  0.543  32   53  ...
#
#    DRB%_players  TRB%_players  AST%_players  STL%_players  BLK%_players  \
# 0     15.669340     10.003326     14.443854      1.839944      1.174243
# 1     15.362375     10.012007     12.532625      1.027785      0.679583
# 2     14.657694     10.419354     14.706986      2.358125      2.867201
# 3     13.617090      9.563000     17.861854      1.920097      4.304944
# 4     15.125660     10.108146     14.598562      1.453403      3.110354
#
#    TOV%_players  USG%_players  ORtg_players  DRtg_players  BPM_players
# 0     12.329424     20.008688    127.632847    114.770694     2.116778
# 1      9.768000     20.000146    115.643889    124.967014    -0.263049
# 2     12.894146     19.995618    102.328681    109.398819    -1.726819
# 3     12.033076     19.991111    111.053958    103.274306    -0.224799
# 4     12.017993     20.008312    133.320278    112.400069     0.879021
#
# [5 rows x 91 columns]

# %%
# split into tm and opp team
df_tm = merged_raw.iloc[::2]
df_opp = merged_raw.iloc[1::2]

# %%
df_tm.reset_index(inplace=True, drop=True)
df_opp.reset_index(inplace=True, drop=True)

# %%
'''
For creating table with tm performance and opp team performance

# drop team name columns for the opp df to prevent duplication
df_opp.drop(columns=['Tm', 'Opp'], inplace=True)
for col_name in df_opp.columns:
    df_opp.rename(columns={col_name: col_name + "_opp"}, inplace=True)
# drop unnecessary columns from df_opp
df_opp.drop(columns=['Date_opp', 'Result_opp'], inplace=True)
merged_final = df_tm.join(df_opp)
# save cleaned data to csv
merged_final.to_csv("./combined_match_data.csv")
'''
# Out:
# '\nFor creating table with tm performance and opp team performance\n\n# drop team name columns for the opp df to prevent duplication\ndf_opp.drop(columns=[\'Tm\', \'Opp\'], inplace=True)\nfor col_name in df_opp.columns:\n    df_opp.rename(columns={col_name: col_name + "_opp"}, inplace=True)\n# drop unnecessary columns from df_opp\ndf_opp.drop(columns=[\'Date_opp\', \'Result_opp\'], inplace=True)\nmerged_final = df_tm.join(df_opp)\n# save cleaned data to csv\nmerged_final.to_csv("./combined_match_data.csv")\n'

# %%
df_opp.columns
# Out:
# Index(['Date', 'Tm', 'Opp', 'Result', 'MP', 'FG', 'FGA', 'FG%', '2P', '2PA',
#        '2P%', '3P', '3PA', '3P%', 'FT', 'FTA', 'FT%', 'PTS', 'FG.1', 'FGA.1',
#        'FG%.1', '2P.1', '2PA.1', '2P%.1', '3P.1', '3PA.1', '3P%.1', 'FT.1',
#        'FTA.1', 'FT%.1', 'PTS.1', 'FG_AVG', 'FGA_AVG', 'FG%_AVG', '2P_AVG',
#        '2PA_AVG', '2P%_AVG', '3P_AVG', '3PA_AVG', '3P%_AVG', 'FT_AVG',
#        'FTA_AVG', 'FT%_AVG', 'PTS_AVG', 'FG_AVG.1', 'FGA_AVG.1', 'FG%_AVG.1',
#        '2P_AVG.1', '2PA_AVG.1', '2P%_AVG.1', '3P_AVG.1', '3PA_AVG.1',
#        '3P%_AVG.1', 'FT_AVG.1', 'FTA_AVG.1', 'FT%_AVG.1', 'PTS_AVG.1',
#        'FG_players', 'FGA_players', 'FG%_players', '3P_players', '3PA_players',
#        '3P%_players', 'FT_players', 'FTA_players', 'FT%_players',
#        'ORB_players', 'DRB_players', 'TRB_players', 'AST_players',
#        'STL_players', 'BLK_players', 'TOV_players', 'PF_players',
#        'PTS_players', '+/-_players', 'TS%_players', 'eFG%_players',
#        '3PAr_players', 'FTr_players', 'ORB%_players', 'DRB%_players',
#        'TRB%_players', 'AST%_players', 'STL%_players', 'BLK%_players',
#        'TOV%_players', 'USG%_players', 'ORtg_players', 'DRtg_players',
#        'BPM_players'],
#       dtype='object')

# %%
df_opp.drop(columns=['Date','Tm','Opp','Result'], inplace=True)
# Out:
# /Users/zhouzijian/Library/Python/3.7/lib/python/site-packages/pandas/core/frame.py:4117: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
# get the diff between team and opp
for col_name in df_opp.columns:
    df_tm[col_name] -= df_opp[col_name]
# Out:
# /usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df_tm.head()
# Out:
#         Date   Tm  Opp     Result  MP  FG  FGA    FG%  2P  2PA  ...  \
# 0  2021/3/27  LAC  PHI  W 122-112   0   6    8  0.023   5    8  ...
# 1  2021/3/27  MIL  NYK   L 96-102   0  -4   -6 -0.016  -2    2  ...
# 2  2021/3/27  HOU  MIN  W 129-107   0  14    7  0.119   9    8  ...
# 3  2021/3/27  DAL  NOP  L 103-112   0  -5    2 -0.073  -6   -3  ...
# 4  2021/3/27  BOS  OKC   W 111-94   0  10   13  0.048   9   13  ...
#
#    DRB%_players  TRB%_players  AST%_players  STL%_players  BLK%_players  \
# 0      0.306965     -0.008681      1.911229      0.812160      0.494660
# 1      1.040604      0.856354     -3.154868      0.438028     -1.437743
# 2      0.118319      0.237764     -2.612667     -0.216451      0.844785
# 3      0.110549     -1.013229      0.323562      0.000597     -0.465271
# 4      0.158014      0.402292      0.302417      0.613111      0.396278
#
#    TOV%_players  USG%_players  ORtg_players  DRtg_players  BPM_players
# 0      2.561424      0.008542     11.988958    -10.196319     2.379826
# 1      0.861069      0.004507     -8.725278      6.124514    -1.502021
# 2     -2.610431      0.014319     24.842083    -21.371736     5.337083
# 3      3.850118      0.030243    -21.961042     10.158194    -2.328035
# 4     -2.840465     -0.013535     14.925347    -16.427500     4.018167
#
# [5 rows x 91 columns]

# %%
df_tm.dropna(inplace=True)
# Out:
# /usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_tm.head()
# Out:
#         Date   Tm  Opp     Result  MP  FG  FGA    FG%  2P  2PA  ...  \
# 0  2021/3/27  LAC  PHI  W 122-112   0   6    8  0.023   5    8  ...
# 1  2021/3/27  MIL  NYK   L 96-102   0  -4   -6 -0.016  -2    2  ...
# 2  2021/3/27  HOU  MIN  W 129-107   0  14    7  0.119   9    8  ...
# 3  2021/3/27  DAL  NOP  L 103-112   0  -5    2 -0.073  -6   -3  ...
# 4  2021/3/27  BOS  OKC   W 111-94   0  10   13  0.048   9   13  ...
#
#    DRB%_players  TRB%_players  AST%_players  STL%_players  BLK%_players  \
# 0      0.306965     -0.008681      1.911229      0.812160      0.494660
# 1      1.040604      0.856354     -3.154868      0.438028     -1.437743
# 2      0.118319      0.237764     -2.612667     -0.216451      0.844785
# 3      0.110549     -1.013229      0.323562      0.000597     -0.465271
# 4      0.158014      0.402292      0.302417      0.613111      0.396278
#
#    TOV%_players  USG%_players  ORtg_players  DRtg_players  BPM_players
# 0      2.561424      0.008542     11.988958    -10.196319     2.379826
# 1      0.861069      0.004507     -8.725278      6.124514    -1.502021
# 2     -2.610431      0.014319     24.842083    -21.371736     5.337083
# 3      3.850118      0.030243    -21.961042     10.158194    -2.328035
# 4     -2.840465     -0.013535     14.925347    -16.427500     4.018167
#
# [5 rows x 91 columns]

# %%
# save to csv
df_tm.to_csv("combined_match_data.csv")
